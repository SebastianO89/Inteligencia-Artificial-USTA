# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianO89/Inteligencia-Artificial-USTA/blob/main/S1_C2_fuzzy_Ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando la libreria

# %%
# !pip install scikit-fuzzy

# %% [markdown]
# # Importando Libreria

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # `Ejericio 2- Graficar variable temperatura`

# %%
Temp=ctrl.Antecedent(np.arange(60,110,1),'Temperatura')
Temp['middle']=fuzz.trapmf(Temp.universe,[60,60,70,80])
Temp['High']=fuzz.trapmf(Temp.universe,[70,80,90,100])
Temp['Very High']=fuzz.trapmf(Temp.universe,[90,100,110,110])
Temp.view()
